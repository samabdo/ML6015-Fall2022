# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Readings" data-toc-modified-id="Readings-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Readings</a></span></li><li><span><a href="#General-Guide" data-toc-modified-id="General-Guide-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>General Guide</a></span></li><li><span><a href="#Copyright" data-toc-modified-id="Copyright-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Copyright</a></span><ul class="toc-item"><li><span><a href="#Copyright-holder" data-toc-modified-id="Copyright-holder-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Copyright holder</a></span></li><li><span><a href="#The-Course-materials-copyright" data-toc-modified-id="The-Course-materials-copyright-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>The Course materials copyright</a></span></li></ul></li><li><span><a href="#Objectives" data-toc-modified-id="Objectives-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Objectives</a></span></li><li><span><a href="#Cross-validation-chart" data-toc-modified-id="Cross-validation-chart-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Cross-validation chart</a></span></li><li><span><a href="#Overfitting-and-underfitting" data-toc-modified-id="Overfitting-and-underfitting-6"><span class="toc-item-num">6&nbsp;&nbsp;</span><a href="https://machinelearningmastery.com/learning-curves-for-diagnosing-machine-learning-model-performance/" target="_blank">Overfitting and underfitting</a></a></span></li><li><span><a href="#Classification-Evaluation-Metrics" data-toc-modified-id="Classification-Evaluation-Metrics-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Classification Evaluation Metrics</a></span></li><li><span><a href="#Other-Evaluation-Metrics" data-toc-modified-id="Other-Evaluation-Metrics-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Other Evaluation Metrics</a></span><ul class="toc-item"><li><span><a href="#What-is-good-MSE-or-R2" data-toc-modified-id="What-is-good-MSE-or-R2-8.1"><span class="toc-item-num">8.1&nbsp;&nbsp;</span><a href="https://vitalflux.com/mean-square-error-r-squared-which-one-to-use/" target="_blank">What is good MSE or R2</a></a></span></li></ul></li><li><span><a href="#Log-Loss-Function:" data-toc-modified-id="Log-Loss-Function:-9"><span class="toc-item-num">9&nbsp;&nbsp;</span><a href="http://wiki.fast.ai/index.php/Log_Loss" target="_blank">Log Loss Function:</a></a></span><ul class="toc-item"><li><span><a href="#Good/bad-log-loss" data-toc-modified-id="Good/bad-log-loss-9.1"><span class="toc-item-num">9.1&nbsp;&nbsp;</span>Good/bad log loss</a></span></li></ul></li><li><span><a href="#Heart_disease-example" data-toc-modified-id="Heart_disease-example-10"><span class="toc-item-num">10&nbsp;&nbsp;</span><a href="https://www.mldata.io/dataset-details/heart_disease/" target="_blank">Heart_disease example</a></a></span><ul class="toc-item"><li><span><a href="#Comparison-between-accuracy/f1-comparison-using-cross-fold" data-toc-modified-id="Comparison-between-accuracy/f1-comparison-using-cross-fold-10.1"><span class="toc-item-num">10.1&nbsp;&nbsp;</span>Comparison between accuracy/f1 comparison using cross-fold</a></span></li><li><span><a href="#StratifiedKFold" data-toc-modified-id="StratifiedKFold-10.2"><span class="toc-item-num">10.2&nbsp;&nbsp;</span>StratifiedKFold</a></span></li><li><span><a href="#PR-curve" data-toc-modified-id="PR-curve-10.3"><span class="toc-item-num">10.3&nbsp;&nbsp;</span>PR-curve</a></span></li><li><span><a href="#AUC-curve" data-toc-modified-id="AUC-curve-10.4"><span class="toc-item-num">10.4&nbsp;&nbsp;</span>AUC curve</a></span></li><li><span><a href="#Training-and-Testing-on-the-whole-dataset" data-toc-modified-id="Training-and-Testing-on-the-whole-dataset-10.5"><span class="toc-item-num">10.5&nbsp;&nbsp;</span>Training and Testing on the whole dataset</a></span></li></ul></li><li><span><a href="#MNIST-database-(Modified-National-Institute-of-Standards-and-Technology-database)" data-toc-modified-id="MNIST-database-(Modified-National-Institute-of-Standards-and-Technology-database)-11"><span class="toc-item-num">11&nbsp;&nbsp;</span><a href="https://en.wikipedia.org/wiki/MNIST_database" target="_blank">MNIST database (Modified National Institute of Standards and Technology database)</a></a></span><ul class="toc-item"><li><span><a href="#Make-the-problem-binary_classification-problem" data-toc-modified-id="Make-the-problem-binary_classification-problem-11.1"><span class="toc-item-num">11.1&nbsp;&nbsp;</span>Make the problem binary_classification problem</a></span></li><li><span><a href="#Is-that-a-good-classifier?" data-toc-modified-id="Is-that-a-good-classifier?-11.2"><span class="toc-item-num">11.2&nbsp;&nbsp;</span>Is that a good classifier?</a></span></li><li><span><a href="#Can-we-conclude-something?" data-toc-modified-id="Can-we-conclude-something?-11.3"><span class="toc-item-num">11.3&nbsp;&nbsp;</span>Can we conclude something?</a></span></li><li><span><a href="#Confusion-matrix" data-toc-modified-id="Confusion-matrix-11.4"><span class="toc-item-num">11.4&nbsp;&nbsp;</span>Confusion matrix</a></span></li><li><span><a href="#Precision-Recall-Tradeoff" data-toc-modified-id="Precision-Recall-Tradeoff-11.5"><span class="toc-item-num">11.5&nbsp;&nbsp;</span>Precision-Recall Tradeoff</a></span><ul class="toc-item"><li><span><a href="#Decision-threshold-and-precision/recall-tradeoff" data-toc-modified-id="Decision-threshold-and-precision/recall-tradeoff-11.5.1"><span class="toc-item-num">11.5.1&nbsp;&nbsp;</span>Decision threshold and precision/recall tradeoff</a></span></li></ul></li></ul></li></ul></div>

# %% [markdown]
# # Readings
#
# 1. Chapter 3 in the syllabus book 1 covers the materials in this notebook and related notebooks. As guidelines for your readings, you may want to:
#     - Study first the notebooks and then read the related topics in Chapter 3 and web links for more knowledge. Or
#     - Read Chapter 3 to get broad vision and then study the notebooks and go through the web links when you need.
# 2. Try to practice the code in Chapter 3 book 1 GiHub.
# 3. You do not need to memorize the code but you can use/modify it in your assignment and project. I will not explain the codes in details; rather, I will just go through its main concepts and the outputs.

# %% [markdown]
# # General Guide
#
# In this jupyter notebook:
# 1. Some items in the table of contents are described totally in this notebook. Others are just links to other jupyter notebooks located in the same folder of this notebook-- you need to click on each link to open it in a new window of the related notebook.
# 2. The student wants to understand not to memorize Chapter 3 concepts. The Chapter has concepts that will be used during the whole course. The student also may want to understand not memorize the code written in the jupyter notebooks.

# %% [markdown]
# # Copyright
#
# ## Copyright holder
#
# Most of the contents of this lectures are taken/modified from the book:
# "Hands-On Machine Learning with Scikit-Learn, Keras, and TensorFlow Concepts, Tools, and Techniques to
# Build Intelligent Systems"-- [link](https://www.amazon.com/Hands-Machine-Learning-Scikit-Learn-TensorFlow/dp/1492032646). Other contents are either developed by the instructor or taken from web links that are cited in the contexts.
#
# ## The Course materials copyright
#
# The Content is made available only for your personal, noncommercial educational, and scholarly use. You may not use the Content for any other purpose, or distribute, post or make the Content available to others unless you obtain any required permission from the copyright holder. Some Content may be provided via streaming or other means that restrict copying; you may not circumvent those restrictions. You may not alter or remove any copyright or other proprietary notices included in the Content. You need to take the permission from the above copyright holder to use the materials and to check the complete Course Materials Copyright section in the course canvas website, as well.

# %% [markdown]
# # Objectives
#
# To understand the following concepts:
# 1. Examples of over/under-fitting problems.
# 2. Classification/regression evaluation metrics.
# 3. Unbalanced ratio between positives/negatives and Stratified Kfold

# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import SGDClassifier
from sklearn.base import clone
from sklearn.base import BaseEstimator

from sklearn.metrics import f1_score,precision_score, recall_score, f1_score, log_loss,precision_recall_curve,  average_precision_score,roc_curve, auc, roc_auc_score,confusion_matrix, classification_report 
from sklearn.model_selection import train_test_split,StratifiedKFold, cross_val_score,cross_val_predict

from tensorflow.keras.datasets import mnist

#scores in https://scikit-learn.org/stable/modules/model_evaluation.html

# %% [markdown]
# # Cross-validation chart
#
# See the white board

# %% [markdown]
# # [Overfitting and underfitting](https://machinelearningmastery.com/learning-curves-for-diagnosing-machine-learning-model-performance/)
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # Classification Evaluation Metrics
#
# ## [Positive vs. Negative](https://www.scribbr.com/statistics/type-i-and-type-ii-errors/):
#
# In clinical domain/test, positive case means patient has a disease and negative case if they have not. Having the null hypothesis is the patient is healthy, then
# <b> False positive (Type I error) </b> when the coming patient has no disease, we by mistake reject the null hypothesis and say they have disease.     What is the problem?
# <b> False negative (Type II error) </b> when the coming patient has disease, we fail to reject null the null hypothesis, and say they have no disease. What is the problem?
#
# ![image.png](attachment:aa7d7b02-e1a6-4f53-ae25-23f4c1739d4d.png)
#
# ## [Precision vs. Recall](https://medium.com/@shrutisaxena0617/precision-vs-recall-386cf9f89488)
#
# ![image.png](attachment:829bc609-44d4-48e5-b87e-2eacef68fb9e.png)
#
# ## [Example 1 — Low Precision, High Recall, and High Specificity](https://towardsdatascience.com/should-i-look-at-precision-recall-or-specificity-sensitivity-3946158aace1)
#
# ![image.png](attachment:7cc7b830-3f20-42c1-b08b-c84a1f48fb1f.png)

# %% [markdown]
# ## [More Information](https://en.wikipedia.org/wiki/Sensitivity_and_specificity)
#
#
# <img style="float: center" src="./images/Supervised-metrics.png" alt="drawing" Hight="600" width="900"/>
#
# [ROC and AUC Reference](http://gim.unmc.edu/dxtests/roc3.htm)
#
# [Supervised metrics](https://en.wikipedia.org/wiki/Precision_and_recall)

# %% [markdown]
# ## F-score, micro and macro
#
#
# ### Multiple class example:
#    1.[Example 1](https://stephenallwright.com/micro-vs-macro-f1-score/).
#    2.[Example 2](https://towardsdatascience.com/micro-macro-weighted-averages-of-f1-score-clearly-explained-b603420b292f).
#
#
# <b> F1 score </b> is a metric which is calculated per class, which means that if you want to calculate the overall F1 score for a dataset with more than one class you will need to aggregate in some way. Micro and macro F1 score are two ways of doing this aggregation.
#
# ![image.png](attachment:7561d94e-dfdf-48a5-ae11-03917b15c205.png)
#
#
# <b> Micro F1 score </b> is the normal F1 formula but calculated using the total number of True Positives (TP), False Positives (FP) and False Negatives (FN), instead of individually for each class.
#
# ![image.png](attachment:23862355-b70a-453d-b2bb-f1b0947faca0.png)
#
#
# <b> Macro F1 score: Imbalance class </b> is the unweighted mean of the F1 scores calculated per class. It is the simplest aggregation for F1 score.
#
# ![image.png](attachment:686bfc71-e73f-4f60-8610-ebc8c770237c.png)

# %% [markdown]
# # Other Evaluation Metrics
#
# <img style="float: center" src="./images/Other-metrics.png" alt="drawing" Hight="500" width="800"/>

# %% [markdown]
# ## [What is good MSE or R2](https://vitalflux.com/mean-square-error-r-squared-which-one-to-use/)
#
# **R2 in terms of MSE**
#
# <center> $R^{2}=1-\frac{MSE}{\sigma^2}$</center>
#
# 1. $R^{2}$ represents the fraction of variance of response variable captured by the regression model rather than the $MSE$ which captures the residual error.
# 2. $MSE$ could be affected by feature scaling method. In general, the smaller $MSE$ means the better algorithm we have.
# 2. The greater $R^{2}$ the better algorithm we have.

# %% [markdown]
# # [Log Loss Function:][1]
#
# 1. __Accuracy__ is the count of predictions where your predicted value equals the actual value. Accuracy is not always a good indicator because of its yes or no nature.
# 2. __Log Loss__ takes into account the uncertainty of your prediction based on how much it varies from the actual label. This gives us a more nuanced view into the performance of our model.
#
# **In binary classification**
#
# <center> $Log Loss= -ylog(p)+(1-y)log(1-p)$ </center>
#
# **In multi-class classification (M > 2)**
#
# <center> $Log Loss= \sum_{c=1}^{M}y_{o,c}log(p_{o,c})$ </center>
#
#
# [1]:http://wiki.fast.ai/index.php/Log_Loss
#
#
# ## Good/bad log loss
#
# Log loss applies to the prediction process in machine learning and applies almost strictly to the probabilities. The lower the log loss, the more accurate predictions your AI will make, meaning its overall accuracy and functionality will rise.
#
# The smaller the log loss value, the better the machine learning process, as the likelihood and prediction errors decrease.

# %% [markdown]
# # [Heart_disease example](https://www.mldata.io/dataset-details/heart_disease/)
#
#
# <b> Objectives </b>
# 1. Comparison between accuracy and f1 results from different folds.
# 2. StratifiedKFold role.
# 3. The comparison between one-fold performance and the whole data performance.

# %%
hdFrame = pd.read_csv("~/DATA/heart_disease_dataset.csv")  # Load the data

# %%
hdFrame.head()

# %%
hdFrame.shape

# %%
X = hdFrame[hdFrame.columns[0:13]]
y = hdFrame[hdFrame.columns[13]]

# %%
X.dtypes

# %%
y.dtypes

# %%
y.value_counts()

# %%
# Here random_state is not hyperparameter but solver is.
logi_clf=LogisticRegression(solver='liblinear', random_state=1)

# %% [markdown]
# ## Comparison between accuracy/f1 comparison using cross-fold

# %%
cross_val_score(logi_clf, X, y, cv=20, scoring="accuracy")

# %%
cross_val_score(logi_clf, X, y, cv=20, scoring="f1")

# %% [markdown]
# ## StratifiedKFold

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42, stratify=y)

# %%
k_fold = StratifiedKFold(n_splits=5,shuffle=True,random_state=2019)

# %%
trainingScores = []
cvScores = []
predictionsBasedOnKFolds = pd.DataFrame(data=[],index=y_train.index,columns=[0,1])
model = logi_clf

for train_index, cv_index in k_fold.split(np.zeros(len(X_train)) ,y_train.ravel()):
    X_train_fold, X_cv_fold = X_train.iloc[train_index,:], X_train.iloc[cv_index,:]
    y_train_fold, y_cv_fold = y_train.iloc[train_index], y_train.iloc[cv_index]
    model.fit(X_train_fold, y_train_fold)
    
    #print(y_train_fold)
    #print(model.predict_proba(X_train_fold)[:,1])
    
    loglossTraining = log_loss(y_train_fold, model.predict_proba(X_train_fold)[:,1])
    trainingScores.append(loglossTraining)
    
    predictionsBasedOnKFolds.loc[X_cv_fold.index,:] = model.predict_proba(X_cv_fold) 
    #print("predictions")
    #print(predictionsBasedOnKFolds)
    #print(model.predict_proba(X_cv_fold))
    #print(model.predict(X_cv_fold))
    loglossCV = log_loss(y_cv_fold, predictionsBasedOnKFolds.loc[X_cv_fold.index,1])
    cvScores.append(loglossCV)
    print('Training Log Loss: ', loglossTraining)
    print('CV Log Loss: ', loglossCV)
    
loglossLogisticRegression = log_loss(y_train, predictionsBasedOnKFolds.loc[:,1])
print('LogisticRegression  Log Loss: ', loglossLogisticRegression)

# %% [markdown]
# ## PR-curve

# %%
preds = pd.concat([y_train,predictionsBasedOnKFolds.loc[:,1]], axis=1)
preds.columns = ['trueLabel','prediction']

# %%
precision, recall, thresholds = precision_recall_curve(preds['trueLabel'],preds['prediction'])
average_precision = average_precision_score(preds['trueLabel'],preds['prediction'])
plt.step(recall, precision, color='k', alpha=0.7, where='post')
plt.fill_between(recall, precision, step='post', alpha=0.3, color='k')

plt.xlabel('Recall')
plt.ylabel('Precision')
plt.ylim([0.0, 1.05])
plt.xlim([0.0, 1.0])
plt.title('Precision-Recall curve: Average Precision = {0:0.2f}'.format(average_precision))

# %% [markdown]
# ## AUC curve

# %%
fpr, tpr, thresholds = roc_curve(preds['trueLabel'],preds['prediction'])
areaUnderROC = auc(fpr, tpr)
plt.figure()
plt.plot(fpr, tpr, color='r', lw=2, label='ROC curve')
plt.plot([0, 1], [0, 1], color='k', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic: Area under the curve = {0:0.2f}'.format(areaUnderROC))
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# ## Training and Testing on the whole dataset

# %%
tr=model.fit(X,y)

# %%
tr_pred=tr.predict(X)

# %%
precision_score(tr_pred,y)

# %%
y_pred = model.predict(X_test)

# %%
precision_score(y_pred,y_test)

# %% [markdown]
# # [MNIST database (Modified National Institute of Standards and Technology database)](https://en.wikipedia.org/wiki/MNIST_database)
#
# MNIST dataset, which is a set of 70,000 small images of digits handwritten by high school students and employees of the US Census Bureau. Each image is labeled with the digit it represents.
#
# <img style="float: center" src="./images/Scikit-LearnBook.png" alt="drawing" Hight="300" width="300"/>
#
#
# <b> objectives </b>
#
# 1. Making the problem binary_classification problem.
# 2. StratifiedKFold role.
# 3. Is that a good classifier?
# 4. Precision/recall threshold analysis.

# %%
#See the Main Book for this example.
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# %%
X_train.shape

# %%
num_pixels = 784
X_train = X_train.reshape(X_train.shape[0],
                         num_pixels)

# %%
X_train.shape

# %%
num_pixels = 784
X_test = X_test.reshape(X_test.shape[0],
                         num_pixels)

# %%
X_test.shape

# %%
y_train.shape

# %%
unique, counts = np.unique(y_train, return_counts=True)
dict(zip(unique, counts))

# %% [markdown]
# ## Make the problem binary_classification problem

# %%
y_train_5 = (y_train == 5)
y_test_5 = (y_test == 5)

# %%
# The distribution of yes/no

unique, counts = np.unique(y_train_5, return_counts=True)
number_classes=dict(zip(unique, counts))
True_Ratio=number_classes[True]/(number_classes[True]+number_classes[False])
print(number_classes)
print('The True Positive ' +str(True_Ratio*100)+ '%')   # Vert imbalance situation

# %%
help(SGDClassifier)

# %%
sgd_clf = SGDClassifier(max_iter=1000, tol=1e-3, random_state=42)
sgd_clf.fit(X_train, y_train_5)

# %%
cross_val_score(sgd_clf, X_train, y_train_5, cv=3, scoring="accuracy")

# %%
# Build your classifier using stratified methods
skfolds = StratifiedKFold(n_splits=3, shuffle=True, random_state=42)

for train_index, test_index in skfolds.split(X_train, y_train_5):
    clone_clf = clone(sgd_clf)
    X_train_folds = X_train[train_index]
    y_train_folds = y_train_5[train_index]
    X_test_fold = X_train[test_index]
    y_test_fold = y_train_5[test_index]

    clone_clf.fit(X_train_folds, y_train_folds)
    y_pred = clone_clf.predict(X_test_fold)
    n_correct = sum(y_pred == y_test_fold)
    print(n_correct / len(y_pred))

# %% [markdown]
# ## Is that a good classifier?
#
# <b> We need to develop by chance classifier to check the accuracy of our classifier </b>

# %%
class Random5Classifier(BaseEstimator):
    def fit(self, X, y=None):
        pass
    def predict(self, X):
        return np.zeros((len(X), 1), dtype=bool)

# %%
random_5_clf = Random5Classifier()
cross_val_score(random_5_clf, X_train, y_train_5, cv=3, scoring="accuracy")

# %% [markdown]
# ## Can we conclude something?

# %% [markdown]
# ## Confusion matrix

# %%
y_train_pred = cross_val_predict(sgd_clf, X_train, y_train_5, cv=3)

# %%
confusion_matrix(y_train_5, y_train_pred)

# %% [markdown]
# <b> TN=53892, FP=687  total of  54579 negatives or falses.
#     FN=1891, TP=3530 total of 5421 positives or trues. </b>

# %% [markdown]
# ## Precision-Recall Tradeoff

# %%
print(precision_score(y_train_5, y_train_pred))
print(recall_score(y_train_5, y_train_pred))
print(f1_score(y_train_5, y_train_pred))

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Decision threshold and precision/recall tradeoff

# %% [markdown]
# ![image.png](attachment:image.png)
