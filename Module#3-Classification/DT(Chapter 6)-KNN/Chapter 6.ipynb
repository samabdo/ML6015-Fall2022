# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Readings" data-toc-modified-id="Readings-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Readings</a></span></li><li><span><a href="#General-Guide" data-toc-modified-id="General-Guide-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>General Guide</a></span></li><li><span><a href="#Copyright" data-toc-modified-id="Copyright-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Copyright</a></span><ul class="toc-item"><li><span><a href="#Copyright-holder" data-toc-modified-id="Copyright-holder-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Copyright holder</a></span></li><li><span><a href="#The-Course-materials-copyright" data-toc-modified-id="The-Course-materials-copyright-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>The Course materials copyright</a></span></li></ul></li><li><span><a href="#Parametric-vs.-Non-parametric-ML-algorithms" data-toc-modified-id="Parametric-vs.-Non-parametric-ML-algorithms-4"><span class="toc-item-num">4&nbsp;&nbsp;</span><a href="https://machinelearningmastery.com/parametric-and-nonparametric-machine-learning-algorithms/" target="_blank">Parametric vs. Non-parametric ML algorithms</a></a></span></li><li><span><a href="#Decision-tree-classifier" data-toc-modified-id="Decision-tree-classifier-5"><span class="toc-item-num">5&nbsp;&nbsp;</span><a href="https://www.inf.unibz.it/~mkacimi/lecture5.pdf" target="_blank">Decision tree classifier</a></a></span><ul class="toc-item"><li><span><a href="#Motivation" data-toc-modified-id="Motivation-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span><a href="https://medium.com/machine-learning-101/chapter-3-decision-trees-theory-e7398adac567" target="_blank">Motivation</a></a></span><ul class="toc-item"><li><span><a href="#Decision-tree-definition:" data-toc-modified-id="Decision-tree-definition:-5.1.1"><span class="toc-item-num">5.1.1&nbsp;&nbsp;</span>Decision tree definition:</a></span></li><li><span><a href="#Decision-tree-components:" data-toc-modified-id="Decision-tree-components:-5.1.2"><span class="toc-item-num">5.1.2&nbsp;&nbsp;</span>Decision tree components:</a></span></li><li><span><a href="#Typical-output-from-the-sub-decision-tree" data-toc-modified-id="Typical-output-from-the-sub-decision-tree-5.1.3"><span class="toc-item-num">5.1.3&nbsp;&nbsp;</span>Typical output from the sub decision tree</a></span></li><li><span><a href="#Here-we-have-two-decisions" data-toc-modified-id="Here-we-have-two-decisions-5.1.4"><span class="toc-item-num">5.1.4&nbsp;&nbsp;</span>Here we have two decisions</a></span></li></ul></li></ul></li><li><span><a href="#Example" data-toc-modified-id="Example-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Example</a></span></li><li><span><a href="#The-three-possible-partition-scenarios:" data-toc-modified-id="The-three-possible-partition-scenarios:-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>The three possible partition scenarios:</a></span></li><li><span><a href="#Attribute-selection-measures:" data-toc-modified-id="Attribute-selection-measures:-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Attribute selection measures:</a></span><ul class="toc-item"><li><span><a href="#Methods" data-toc-modified-id="Methods-8.1"><span class="toc-item-num">8.1&nbsp;&nbsp;</span>Methods</a></span></li></ul></li><li><span><a href="#Entropy" data-toc-modified-id="Entropy-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Entropy</a></span><ul class="toc-item"><li><span><a href="#Math-definition-of-entropy" data-toc-modified-id="Math-definition-of-entropy-9.1"><span class="toc-item-num">9.1&nbsp;&nbsp;</span>Math definition of entropy</a></span></li></ul></li><li><span><a href="#Information-Gain" data-toc-modified-id="Information-Gain-10"><span class="toc-item-num">10&nbsp;&nbsp;</span>Information Gain</a></span><ul class="toc-item"><li><span><a href="#Steps" data-toc-modified-id="Steps-10.1"><span class="toc-item-num">10.1&nbsp;&nbsp;</span>Steps</a></span></li><li><span><a href="#Entropy-and-information-gain-example" data-toc-modified-id="Entropy-and-information-gain-example-10.2"><span class="toc-item-num">10.2&nbsp;&nbsp;</span><a href="https://victorzhou.com/blog/information-gain/" target="_blank">Entropy and information gain example</a></a></span></li></ul></li><li><span><a href="#Solution-of-the-above-example" data-toc-modified-id="Solution-of-the-above-example-11"><span class="toc-item-num">11&nbsp;&nbsp;</span><a href="https://www.inf.unibz.it/~mkacimi/lecture5.pdf" target="_blank">Solution of the above example</a></a></span><ul class="toc-item"><li><span><a href="#The-first-step-of-information-gain" data-toc-modified-id="The-first-step-of-information-gain-11.1"><span class="toc-item-num">11.1&nbsp;&nbsp;</span><a href="https://www.inf.unibz.it/~mkacimi/lecture5.pdf" target="_blank">The first step of information gain</a></a></span></li><li><span><a href="#The-second-step-of-information-gain" data-toc-modified-id="The-second-step-of-information-gain-11.2"><span class="toc-item-num">11.2&nbsp;&nbsp;</span><a href="https://www.inf.unibz.it/~mkacimi/lecture5.pdf" target="_blank">The second step of information gain</a></a></span></li><li><span><a href="#The-third-step-of-information-gain" data-toc-modified-id="The-third-step-of-information-gain-11.3"><span class="toc-item-num">11.3&nbsp;&nbsp;</span><a href="https://www.inf.unibz.it/~mkacimi/lecture5.pdf" target="_blank">The third step of information gain</a></a></span></li></ul></li><li><span><a href="#Decision-Tree-(DT)-and-overfitting" data-toc-modified-id="Decision-Tree-(DT)-and-overfitting-12"><span class="toc-item-num">12&nbsp;&nbsp;</span>Decision Tree (DT) and overfitting</a></span><ul class="toc-item"><li><span><a href="#Pruning-solution" data-toc-modified-id="Pruning-solution-12.1"><span class="toc-item-num">12.1&nbsp;&nbsp;</span><a href="https://en.wikipedia.org/wiki/Decision_tree_pruning" target="_blank">Pruning solution</a></a></span></li><li><span><a href="#Pruning-types" data-toc-modified-id="Pruning-types-12.2"><span class="toc-item-num">12.2&nbsp;&nbsp;</span><a href="https://www.saedsayad.com/decision_tree_overfitting.htm" target="_blank">Pruning types</a></a></span></li><li><span><a href="#Pruning-in-python" data-toc-modified-id="Pruning-in-python-12.3"><span class="toc-item-num">12.3&nbsp;&nbsp;</span><a href="https://statinfer.com/204-3-10-pruning-a-decision-tree-in-python/" target="_blank">Pruning in python</a></a></span><ul class="toc-item"><li><span><a href="#Data-preparation" data-toc-modified-id="Data-preparation-12.3.1"><span class="toc-item-num">12.3.1&nbsp;&nbsp;</span>Data preparation</a></span></li><li><span><a href="#DT-in-sklearn" data-toc-modified-id="DT-in-sklearn-12.3.2"><span class="toc-item-num">12.3.2&nbsp;&nbsp;</span>DT in sklearn</a></span></li><li><span><a href="#Run-DT-with-visualization" data-toc-modified-id="Run-DT-with-visualization-12.3.3"><span class="toc-item-num">12.3.3&nbsp;&nbsp;</span>Run DT with visualization</a></span></li><li><span><a href="#Run-DT-with-different-max_depth" data-toc-modified-id="Run-DT-with-different-max_depth-12.3.4"><span class="toc-item-num">12.3.4&nbsp;&nbsp;</span>Run DT with different max_depth</a></span></li></ul></li></ul></li><li><span><a href="#Extra-readings-for-DT:" data-toc-modified-id="Extra-readings-for-DT:-13"><span class="toc-item-num">13&nbsp;&nbsp;</span>Extra readings for DT:</a></span><ul class="toc-item"><li><span><a href="#Can-we-re-use-features-at-each-node-when-generating-a-decision-tree?" data-toc-modified-id="Can-we-re-use-features-at-each-node-when-generating-a-decision-tree?-13.1"><span class="toc-item-num">13.1&nbsp;&nbsp;</span><a href="https://datascience.stackexchange.com/questions/10713/does-random-forest-re-use-features-at-each-node-when-generating-a-decision-tree" target="_blank">Can we re-use features at each node when generating a decision tree?</a></a></span></li><li><span><a href="#Useful-materials-from-Medium" data-toc-modified-id="Useful-materials-from-Medium-13.2"><span class="toc-item-num">13.2&nbsp;&nbsp;</span>Useful materials from Medium</a></span></li></ul></li><li><span><a href="#K-nearest-neigbors-algorithm" data-toc-modified-id="K-nearest-neigbors-algorithm-14"><span class="toc-item-num">14&nbsp;&nbsp;</span><a href="https://blog.usejournal.com/a-quick-introduction-to-k-nearest-neighbors-algorithm-62214cea29c7" target="_blank">K-nearest neigbors algorithm</a></a></span><ul class="toc-item"><li><span><a href="#KNN-Algorithm" data-toc-modified-id="KNN-Algorithm-14.1"><span class="toc-item-num">14.1&nbsp;&nbsp;</span><a href="https://towardsdatascience.com/machine-learning-basics-with-the-k-nearest-neighbors-algorithm-6a6e71d01761" target="_blank">KNN Algorithm</a></a></span><ul class="toc-item"><li><span><a href="#How-to-choose-K-in-KNN-algorithm-(Naive-steps)" data-toc-modified-id="How-to-choose-K-in-KNN-algorithm-(Naive-steps)-14.1.1"><span class="toc-item-num">14.1.1&nbsp;&nbsp;</span>How to choose K in KNN algorithm (Naive steps)</a></span></li><li><span><a href="#What-is-the-best-K-and-what-is-the-next-step?" data-toc-modified-id="What-is-the-best-K-and-what-is-the-next-step?-14.1.2"><span class="toc-item-num">14.1.2&nbsp;&nbsp;</span>What is the best K and what is the next step?</a></span></li></ul></li></ul></li><li><span><a href="#Statistical-metrics-used-commonly-in-regression-family" data-toc-modified-id="Statistical-metrics-used-commonly-in-regression-family-15"><span class="toc-item-num">15&nbsp;&nbsp;</span><a href="http://www.csam.or.kr/journal/view.html?doi=10.29220/CSAM.2020.27.3.301" target="_blank">Statistical metrics used commonly in regression-family</a></a></span></li><li><span><a href="#Collinearity-and-Multi-collinearity" data-toc-modified-id="Collinearity-and-Multi-collinearity-16"><span class="toc-item-num">16&nbsp;&nbsp;</span>Collinearity and Multi-collinearity</a></span></li><li><span><a href="#Variance-Inflation-Factor-(VIF)" data-toc-modified-id="Variance-Inflation-Factor-(VIF)-17"><span class="toc-item-num">17&nbsp;&nbsp;</span><a href="https://corporatefinanceinstitute.com/resources/knowledge/other/variance-inflation-factor-vif/" target="_blank">Variance Inflation Factor (VIF)</a></a></span></li><li><span><a href="#DT-Resources-to-read-and-watch:" data-toc-modified-id="DT-Resources-to-read-and-watch:-18"><span class="toc-item-num">18&nbsp;&nbsp;</span>DT Resources to read and watch:</a></span></li><li><span><a href="#Cohen's-kappa-($\kappa$)" data-toc-modified-id="Cohen's-kappa-($\kappa$)-19"><span class="toc-item-num">19&nbsp;&nbsp;</span>Cohen's kappa ($\kappa$)</a></span><ul class="toc-item"><li><span><a href="#[Simple-example][https://en.wikipedia.org/wiki/Cohen%27s_kappa]" data-toc-modified-id="[Simple-example][https://en.wikipedia.org/wiki/Cohen%27s_kappa]-19.1"><span class="toc-item-num">19.1&nbsp;&nbsp;</span>[Simple example][<a href="https://en.wikipedia.org/wiki/Cohen%27s_kappa%5D" target="_blank">https://en.wikipedia.org/wiki/Cohen%27s_kappa]</a></a></span></li><li><span><a href="#Kappa-for-binary-classification-confusion-matrix" data-toc-modified-id="Kappa-for-binary-classification-confusion-matrix-19.2"><span class="toc-item-num">19.2&nbsp;&nbsp;</span>Kappa for binary classification confusion matrix</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Readings
#
# 1. Chapter 6 in the syllabus book 1 covers the materials in this notebook and related notebooks. As guidelines for your readings, you may want to:
#     - Study first the notebooks and then read the related topics in Chapter 6 and web links for more knowledge. Or
#     - Read Chapter 6 to get broad vision and then study the notebooks and go through the web links when you need.
# 2. Try to practice the code in Chapter 6 book 1 GiHub.
# 3. You do not need to memorize the code but you can use/modify it in your assignment and project. I will not explain the codes in details; rather, I will just go through its main concepts and the outputs.

# %% [markdown]
# # General Guide
#
# In this jupyter notebook:
# 1. Some items in the table of contents are described totally in this notebook.
# 2. The student wants to understand not to memorize Chapter 6 concepts. The Chapter has concepts that will be used during the whole course. The student also may want to understand not memorize the code written in the jupyter notebooks.

# %% [markdown]
# # Copyright
#
# ## Copyright holder
#
# Most of the contents of this lectures are taken/modified from the book:
# "Hands-On Machine Learning with Scikit-Learn, Keras, and TensorFlow Concepts, Tools, and Techniques to
# Build Intelligent Systems"-- [link](https://www.amazon.com/Hands-Machine-Learning-Scikit-Learn-TensorFlow/dp/1492032646). Other contents are either developed by the instructor or taken from web links that are cited in the contexts.
#
# ## The Course materials copyright
#
# The Content is made available only for your personal, noncommercial educational, and scholarly use. You may not use the Content for any other purpose, or distribute, post or make the Content available to others unless you obtain any required permission from the copyright holder. Some Content may be provided via streaming or other means that restrict copying; you may not circumvent those restrictions. You may not alter or remove any copyright or other proprietary notices included in the Content. You need to take the permission from the above copyright holder to use the materials and to check the complete Course Materials Copyright section in the course canvas website, as well.

# %% [markdown]
# # [Parametric vs. Non-parametric ML algorithms](https://machinelearningmastery.com/parametric-and-nonparametric-machine-learning-algorithms/)
#
# 1. Parametric ML algorithm is the algorithm that has finite set of parameters of fixed size independently from the number of training examples. It assumes usually a prior normal distribution for the population.
#     - Examples:
#         - Regression-family.
#         - Simple neural network and Perceptron.
#         - Naive Bayes.
# 2. Non-Parametric ML algorithm is the algorithm that does not assume any prior knowledge for population distribution and usually its parameters depend on the data points or size.
#     - Examples:
#         - Decision Tree.
#         - K-nearest neighbors algorithm.
#         - RBF SVM.
#
# <b> Benefits and limitations </b>
# 1. Parametric Machine Learning Algorithms:
#   - Benefits: Simpler, fast, less data.
#   - Limitations: Constrained, limited complexity, poor fit.
# 2. Non-Parametric Machine Learning Algorithms:
#   - Benefits: Flexible, no assumptions,high performance.
#   - Limitations: More data, slow, overfitting.

# %% [markdown]
# # [Decision tree classifier][1]
#
#
# <b> Most of this lecture are taken from or spired by the [pdf][1] and other links. I uploaded the pdf in my GitHub folder. </b>
#
#
# ## [Motivation][2]
#
#
# Suppose we have two classes represented by black circle and blue squares:
#
#
#
# <img style="float:center" src="./images/Splitting_Space.png" alt="drawing" height="200" width="300"/>
#
# We will need more than one line, to divide into classes, such as:
#
# <img style="float:center" src="./images/Splitting_Space_MoreLines.png" alt="drawing" height="200" width="300"/>
#
#
# We need two lines here one separating according to threshold value of x and other for threshold value of y.
#
# <b> So when does it terminate: </b>
#
#
# 1. Either, it has divided into classes that are pure (only containing members of single class ).
# 2. Or, Some criteria of classifier attributes are met.
#
# ### Decision tree definition:
#
# <b> Decision Tree Classifier </b>, repetitively divides <b> (in a divide and conquare manner) </b> the working area(plot) into sub part by identifying lines. (repetitively because there may be two distant regions of same class divided by other as shown in image below).
#
#
# ### Decision tree components:
#
#
#
# Given our example:
#
# <img style="float:center" src="./images/Example-Semi.png" alt="drawing" height="400" width="600"/>
#
#
# Sub-Tree like the below:
#
# <img style="float:center" src="./images/DT-Example.png" alt="drawing" height="300" width="500"/>
#
#
# <b> Components </b>
#
# 1. Root node: The topmost. (Here is the age?)
# 2. Branches: Represent the outcomes of tests. (e.g. here we have three branches from age?)
# 3. Leaf nodes: Terminal nodes that holds class labels. (Here we have 5 nodes)
# 4. Internal nodes: Non leaves or root nodes that need further splitting?
#
#
# ### Typical output from the sub decision tree
#
# Typical output is a rule-based system that summarizes the DT branches:
#
#
# if (age == youth) and (student=no) then Class = no <br/>
#     &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; else if (age == youth) and (student=yes) then Class = yes <br/>
# else if (age == Middle-aged) then Class = yes <br/>
# else if (age=senior) and (credit-rating=fair) then Class = no <br/>
#     &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; if (age == senior) and (credit-rating=Excellent) then Class = yes <br/>
#
#
#
# ### Here we have two decisions
#
#
#
# 1. What is the best attribute or feature to split?
# 2. When do we have to stop?
#
#
# [1]:https://www.inf.unibz.it/~mkacimi/lecture5.pdf
# [2]:https://medium.com/machine-learning-101/chapter-3-decision-trees-theory-e7398adac567

# %% [markdown]
# # Entropy
#
# The Entropy is a measure of the average information content one is missing when one does not know the value of the random variable. Entropy can be roughly thought of as how much variance the data has. <br>
#
#
# <img style="float:center" src="./images/Entropy.png" alt="drawing" height="300" width="500"/>
#
#
# ## Math definition of entropy
#
# Given that $X$ takes $n$ values $V_{1},V_{2},\cdots,V_{n}$ and
#
# <center> $P(X=V_{1})=p_{1}, P(X=V_{2})=p_{2},\cdots, P(X=V_{n})=p_{n}$ </center>
#
# The entropy is the smallest number of bits $(H(x))$, on average, per symbol, needed to transmit the symbols drawn from distribution of X is given by: <br/> <br/>
# <center>$ H(X) = - \sum_{i}^n p_{i}\log_{2}(p_{i})$  </center>
#
# [<b>Example</b>][2]
#
# 1. Consider we have X with 2 equal possibilties $P(X=A)=P(X=B)\frac{1}{2}$. So, $H(X)=-0.5\log_{2}0.5-0.5\log_{2}0.5=1$
# 2. Consider we have X with 2 unequal possibilties $P(X=A)=0.36$ and $P(X=B)=0.64$. So,  $H(X)=-0.36\log_{2}0.36-0.64\log_{2}0.64 =0.94$
#
#
# <b> High Entropy </b>
# 1. X is from a uniform like distribution.
# 2. Flat histogram.
# 3. Values sampled from it are less predictable.
#
# <b> Low Entropy </b>
#
# 1. X is from a varied (peaks and valleys) distribution
# 2. Histogram has many lows and highs
# 3. Values sampled from it are more predictable
#
#
# [1]:https://study.com/academy/lesson/what-is-entropy-definition-law-formula.html
# [2]:http://saedsayad.com/decision_tree.htm

# %% [markdown]
# [Youtube](https://www.youtube.com/watch?v=ZVR2Way4nwQ)

# %% [markdown]
# # Example
#
#
# <b> Given our example: </b>
#
# <img style="float:center" src="./images/Example-Semi.png" alt="drawing" height="400" width="600"/>
#
# <b> Let us select: <u> age</u> </b>
#
#
# <img style="float:center" src="./images/Age-Example.png" alt="drawing" height="400" width="600"/>
#
# <img style="float:center" src="./images/Age-Splittting-Middle-aged.png" alt="drawing" height="400" width="600"/>
#
#
#
# <b> Let us select: <u> student</u> </b> based on our selection for <b> age </b>
#
# <img style="float:center" src="./images/Student-Example.png" alt="drawing" height="400" width="600"/>
#
# <img style="float:center" src="./images/Student-Example-Majority.png" alt="drawing" height="400" width="600"/>
#
# <img style="float:center" src="./images/Student-Example-Selection.png" alt="drawing" height="400" width="600"/>
#
#
# <b> And so on</b>

# %% [markdown]
# # The three possible partition scenarios:
#
# <img style="float:center" src="./images/Partitioning Scenarios.png" alt="drawing" height="400" width="600"/>
#
#
# 1. Continuous feature:
#     - Sort all values in an ascending order.
#     - Average each two consequence values (call it for example, $A_{vi}$)
#     - Split on each $A_{vi}$ and calculate the selection attribute measure.
# 2. Categorical feature:
#     - Split on each categorical value.
# 3. Ordinal feature:
#     - Order the ranks.
#     - Split on all ranks except the largest.

# %% [markdown]
# # Attribute selection measures:
#
# The measures are heurstic methods for selecting the splitting criterion that best seperates a given data partition D. We aim to have a pure partition with all tuples or data points belonging to the same class.
#
# <b> Attribute selection measures (splitting rules) </b>
# 1. Determine how the tuples at a given node are to be split.
# 2. Provide ranking for each attribute describing the tuples.
# 3. The attribute with highest score is chosen.
# 4. Determine a split point or a splitting subset.
#
# ## Methods
# 1. Information gain
# 2. Gain ratio
# 3. Gini Index
#
# <b> All these methods are based on the concept of </b> [Entropy][1]
#
# [1]:https://study.com/academy/lesson/what-is-entropy-definition-law-formula.html

# %% [markdown]
# # Information Gain
#
# It is the approach that minimizes the expected number of tests needed to classify a given tuple and guarantee a simple tree.
#
#
#
# ## Steps
#
# 1. Calculate entropy needed to classify a data point from all data points.
# <br/>
# <center> Info$(D) = -\sum_{i}^mp_{i}\log_{2}(p_{i}) $ </center>
# <br/>
# 2. For each attribute, compute the amount of information needed to arrive at an exact classification after portioning using that attribute:
# <br/>
# <center> Info$_{A}(D) = -\sum_{j}^v\frac{\lvert D_{j}\rvert}{\lvert D\rvert} $info $(D_{j})$ </center>
# <br/>
# 3. Compute Infrmation Gain by branching on each attribute or feature A is:
# <br/>
# <center> Gain$(A) =$ Info $(D) - $ info$_{A}(D)$ </center>
# <br/>
#
# 4.Select the attribute with the highest information gain (based on the work by Shannon on information theory). This attribute:
#    - minimizes the information needed to classify the tuples in the resulting partitions.
#    - reflects the least randomness or “impurity” in these partitions.
#
#
# ## [Entropy and information gain example](https://victorzhou.com/blog/information-gain/)

# %% [markdown]
# # [Solution of the above example][1]
#
# ## [The first step of information gain][1]
#
#
#
# To calculate the expected information or the entropy needed to classify a data point from all data points. <br/><br/>
# <center> Info$(D) = -\sum_{i}^mp_{i}\log_{2}(p_{i}) $ </center>
#
# <br/><br/>
#
# <img style="float:center" src="./images/First-Step.png" alt="drawing" height="500" width="700"/>
#
# [1]:https://www.inf.unibz.it/~mkacimi/lecture5.pdf

# %% [markdown]
# ## [The second step of information gain][1]
#
#
#
# For each attribute, compute the amount of information needed to arrive at an exact classification after portioning using that attribute: <br/><br/>
# <center> Info$_{A}(D) = -\sum_{j}^v\frac{\lvert D_{j}\rvert}{\lvert D\rvert} $info $(D_{j})$ </center>
#
#
#
# <br/><br/>
#
#
# <img style="float:center" src="./images/Second-Step.png" alt="drawing" height="500" width="700"/>
#
#
# [1]:https://www.inf.unibz.it/~mkacimi/lecture5.pdf

# %% [markdown]
# ## [The third step of information gain][1]
#
#
#
# - Compute Infrmation Gain by branching on each attribute or feature A is:
#
#
# <center> Gain$(A) =$ Info $(D) - $ info$_{A}(D)$ </center>
#
# - Information gain is the expected reduction in the information requirements caused by knowing the value of A.
#
# -  The attribute A with the highest information gain (Gain(A)), is chosen as the splitting attribute at node N
#
#
# <br/><br/>
#
#
# <img style="float:center" src="./images/Third-Step.png" alt="drawing" height="500" width="700"/>
#
#
#
#
#
#
# [1]:https://www.inf.unibz.it/~mkacimi/lecture5.pdf

# %% [markdown]
# # Decision Tree (DT) and overfitting
#
# ## [Pruning solution][1]
#
# To cut sub-tree(s) (nodes) from the tree that add very little to the classification power of the tree to:
# 1. Increase the proformance.
# 2. Reduce the model comlexity and the overfitting respectively.
#
# ## [Pruning types][2]
#
# We may try to:
# 1. <u> <b> pre-prune</b></u> a DT by stoping growring the tree early (Early stopping).
# 2. <u> <b> post-prune</b></u> a DT after we build the tree to go from up to bottom or from bottom to up.
#
# In all cases, [we want to use][3]:
# 1. The validation dataset; pruned subtree(s) as a hyper-paramter.
# 2. Use some heuristics such as:
#     - Max leaf_nodes, Min samples_leaf, and/or Max depth (Usually in the early stopping method).
#     - Reducing or estimation classification error in the validation dataset (Usually in post-pruning).
#     - Information theary methods (e.g. Chi-squared, information gain, gain ratio,...) in both pruning types.
#
# ## [Pruning in python][4]
#
# Pruning helps us to avoid overfitting. Generally it is preferred to have a simple model, it avoids overfitting issue. Any additional split that does not add significant value is not worth while.<br/><br/>
# We can avoid overfitting by changing  hyper-parameters like
#   - max_leaf_nodes
#   - min_samples_leaf
#   - max_depth
#
#
#
#
# [1]:https://en.wikipedia.org/wiki/Decision_tree_pruning
# [2]:https://www.saedsayad.com/decision_tree_overfitting.htm
# [3]:https://pdfs.semanticscholar.org/025b/8c109c38dc115024e97eb0ede5ea873fffdb.pdf
# [4]:https://statinfer.com/204-3-10-pruning-a-decision-tree-in-python/

# %% [markdown]
# ### Data preparation

# %%
#All-in-one:
import pandas as pd
from sklearn.preprocessing import MinMaxScaler

pima= pd.read_csv("~/DATA/pima.csv")  # Load the data
X = pima[pima.columns[0:8]]
y = pima[pima.columns[8]]


scaler = MinMaxScaler(copy=True,feature_range=(0, 1))
rescaledX=scaler.fit_transform(X)

# %%
from sklearn.model_selection import StratifiedKFold,train_test_split
k_fold = StratifiedKFold(n_splits=5,shuffle=True,random_state=2019)
X_train, X_test, y_train, y_test = train_test_split(rescaledX, y, test_size=0.33, random_state=2019, stratify=y)

# %%
import numpy as np
import warnings
warnings.filterwarnings('ignore')

import sklearn.tree
from sklearn.metrics import accuracy_score,confusion_matrix

# %% [markdown]
# ### DT in sklearn

# %%
import sklearn.tree
help (sklearn.tree.DecisionTreeClassifier)
# Out:
# Help on class DecisionTreeClassifier in module sklearn.tree._classes:
#
# class DecisionTreeClassifier(sklearn.base.ClassifierMixin, BaseDecisionTree)
#  |  DecisionTreeClassifier(*, criterion='gini', splitter='best', max_depth=None, min_samples_split=2, min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_features=None, random_state=None, max_leaf_nodes=None, min_impurity_decrease=0.0, min_impurity_split=None, class_weight=None, ccp_alpha=0.0)
#  |
#  |  A decision tree classifier.
#  |
#  |  Read more in the :ref:`User Guide <tree>`.
#  |
#  |  Parameters
#  |  ----------
#  |  criterion : {"gini", "entropy"}, default="gini"
#  |      The function to measure the quality of a split. Supported criteria are
#  |      "gini" for the Gini impurity and "entropy" for the information gain.
#  |
#  |  splitter : {"best", "random"}, default="best"
#  |      The strategy used to choose the split at each node. Supported
# ...

# %% [markdown]
# ### Run DT with visualization

# %%
confusionMatrix=[]
Results=[]
clf=sklearn.tree.DecisionTreeClassifier(max_depth=5)
clf.fit(X_train,y_train)
with open('DTout.txt', "w") as f:
    f = sklearn.tree.export_graphviz(clf, 
                        class_names=['No','Yes'],
                        feature_names= pima.columns[0:8],
                        rounded=True,
                        filled=True,
                        out_file=f)



pred =clf.predict(X_test)
tn, fp, fn, tp=confusion_matrix(y_test,pred).ravel()
confusionMatrix.append([tn, fp, fn, tp])
Results.append(accuracy_score(y_test, pred))


print(Results[0])
print(confusionMatrix[0])
# Out:
# 0.7401574803149606
# [143, 22, 44, 45]

# %% [markdown]
# To draw the below figure in the web browser:
#
# 1. Retrieve the output [text file][1]
# 2. Cut and paste the content and Go to the http://www.webgraphviz.com/ to visualize.
#
# [1]:./DTout.txt

# %% [markdown]
# ### Run DT with different max_depth

# %%
confusionMatrix=[]
Results=[]
clf=sklearn.tree.DecisionTreeClassifier(max_depth=5)
clf.fit(X_train,y_train)
pred =clf.predict(X_test)
tn, fp, fn, tp=confusion_matrix(y_test,pred).ravel()
confusionMatrix.append([tn, fp, fn, tp])
Results.append(accuracy_score(y_test, pred))

clf=sklearn.tree.DecisionTreeClassifier(max_depth=7)
clf.fit(X_train,y_train)
pred =clf.predict(X_test)
tn, fp, fn, tp=confusion_matrix(y_test,pred).ravel()
confusionMatrix.append([tn, fp, fn, tp])
Results.append(accuracy_score(y_test, pred))


clf=sklearn.tree.DecisionTreeClassifier(max_depth=9)
clf.fit(X_train,y_train)
pred =clf.predict(X_test)
tn, fp, fn, tp=confusion_matrix(y_test,pred).ravel()
confusionMatrix.append([tn, fp, fn, tp])
Results.append(accuracy_score(y_test, pred))

clf=sklearn.tree.DecisionTreeClassifier(max_depth=11)
clf.fit(X_train,y_train)
pred =clf.predict(X_test)
tn, fp, fn, tp=confusion_matrix(y_test,pred).ravel()
confusionMatrix.append([tn, fp, fn, tp])
Results.append(accuracy_score(y_test, pred))

print(Results)
print(confusionMatrix)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_111/44035670.py in <module>
#       1 confusionMatrix=[]
#       2 Results=[]
# ----> 3 clf=sklearn.tree.DecisionTreeClassifier(max_depth=5)
#       4 clf.fit(X_train,y_train)
#       5 pred =clf.predict(X_test)
#
# NameError: name 'sklearn' is not defined

# %% [markdown]
# # Extra readings for DT:
#
# ## [Can we re-use features at each node when generating a decision tree?](https://datascience.stackexchange.com/questions/10713/does-random-forest-re-use-features-at-each-node-when-generating-a-decision-tree)
#
# <b> See the below DT </b>
# ![image.png](attachment:image.png)
#
#
# ## Useful materials from Medium
#
# 1. [The Basics of Decision Trees](https://medium.datadriveninvestor.com/the-basics-of-decision-trees-e5837cc2aba7)
# 2. [Classification in Decision Tree — A Step by Step CART (Classification And Regression Tree](https://medium.com/analytics-vidhya/classification-in-decision-tree-a-step-by-step-cart-classification-and-regression-tree-8e5f5228b11e)
# 3. [Regression in Decision Tree — A Step by Step CART (Classification And Regression Tree)](https://arifromadhan19.medium.com/regrssion-in-decision-tree-a-step-by-step-cart-classification-and-regression-tree-196c6ac9711e)

# %% [markdown]
# # [K-nearest neigbors algorithm][1]
#
# K-nearest neighbors algorithm (k-NN) is <b> a non-parametric or instance-based or lazy </b> method used for classification and regression. In both cases, the input consists of the k closest training examples in the feature space.
#
#
# <img style="float: center" src="./images/KNN.png" alt="drawing" height="300" width="400"/>
#
#
# ## [KNN Algorithm][2]
#
#
# 1. Load the data and [prepare the data][5].
#     - Rescale the data between 0,1.
#     - Address missing data.
#     - Lower dimensionality.
# 2. Initialize K to your chosen number of neighbors. K is a hyper-parameter.
# 3. For each example in the data
#  - Calculate [the distance][3] between the query example and the current example from the data.
#        - Remember L-norm
#  - Add the distance and the index of the example to an ordered collection
# 4. Sort the ordered collection of distances and indices from smallest to largest (in ascending order) by the distances
# 5. Pick the first K entries from the sorted collection
# 6. Get the labels of the selected K entries.
# 7. If [regression][4], return the mean of the K labels.
# 8. If classification, return the mode of the K labels.
#
#
# [1]:https://blog.usejournal.com/a-quick-introduction-to-k-nearest-neighbors-algorithm-62214cea29c7
# [2]:https://towardsdatascience.com/machine-learning-basics-with-the-k-nearest-neighbors-algorithm-6a6e71d01761
# [3]:https://towardsdatascience.com/importance-of-distance-metrics-in-machine-learning-modelling-e51395ffe60d
# [4]:https://www.saedsayad.com/k_nearest_neighbors_reg.htm
# [5]:https://machinelearningmastery.com/k-nearest-neighbors-for-machine-learning/

# %% [markdown]
# ### How to choose K in KNN algorithm (Naive steps)
#
# The selection of K leads to underfitting or overfitting. Very small K leads the model to be sensitive to noise and very large K leads the model to be computationally expensive.  Try the follwing:
#
# 1. if the class is binary, then select K to be odd to avoid ties.
# 2. if multi-class, then a rule of thumb is $K=\sqrt n$ where $n$ is the size of data points.
# 3. However, the ideal one is to use training and testing datasets as the below example.

# %% [markdown]
# ### What is the best K and what is the next step?

# %%
from sklearn.datasets import load_breast_cancer
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt


cancer = load_breast_cancer()
X_train, X_test, y_train, y_test = train_test_split(
    cancer.data, cancer.target, stratify=cancer.target, random_state=66)

training_accuracy = []
test_accuracy = []
# try n_neighbors from 1 to 10
neighbors_settings = range(1, 11)

for n_neighbors in neighbors_settings:
    # build the model
    clf = KNeighborsClassifier(n_neighbors=n_neighbors)
    clf.fit(X_train, y_train)
    # record training set accuracy
    training_accuracy.append(clf.score(X_train, y_train))
    # record generalization accuracy
    test_accuracy.append(clf.score(X_test, y_test))
    
plt.plot(neighbors_settings, training_accuracy, label="training accuracy")
plt.plot(neighbors_settings, test_accuracy, label="test accuracy")
plt.ylabel("Accuracy")
plt.xlabel("n_neighbors")
plt.legend()

# %% [markdown]
# # [Statistical metrics used commonly in regression-family](http://www.csam.or.kr/journal/view.html?doi=10.29220/CSAM.2020.27.3.301)
#
# 1. <b> Akaike information criterion (AIC) </b>: is an estimator of prediction error and thereby relative quality of statistical models for a given set of data. Given a collection of models for the data, AIC estimates the quality of each model, relative to each of the other models. Thus, AIC provides a means for model selection. the model with the lowest AIC is preferred.
# <br/>
# <center> $AIC=-2\hat {L}+2k$ </center>
# <br/>
#
# 2. <b> Schwarz’s Bayesian information criterion (BIC) </b> is a criterion for model selection among a finite set of models; the model with the lowest BIC is preferred.
#
# <br/>
# <center> $BIC=-2\hat {L}+2\log{n}$ </center>
# <br/>
#
# Where k be the number of estimated parameters in the model; $\hat {L}$ be the maximum value of the likelihood function for the model; n is the number of data points.
# The penalty discourages overfitting, which is desired because increasing the number of parameters in the model almost always improves the goodness of the fit.
#
#
# <b> Both BIC and AIC assume independent and identical distributions of the data points </b>

# %% [markdown]
# # Collinearity and Multi-collinearity
#
# <b> Collinearity is a phenomenon that two or more features depend on each other and when you have many features depend on each other, that will cause multi-collinearity phenomenon </b>
#
# # [Variance Inflation Factor (VIF)](https://corporatefinanceinstitute.com/resources/knowledge/other/variance-inflation-factor-vif/)
#
#
# <b> Goals: </b>
# 1. Detect the Multi-collinearity.
# 2. Reduce the variance by removing the variables affected by collinearity with VIF $\ge$ a threshold (e.g., 5).
#
# Here is the [code in python](https://www.statology.org/how-to-calculate-vif-in-python/)

# %% [markdown]
# # DT Resources to read and watch:
#
# 1. Readings:
#   - [Reading 1](https://www.inf.unibz.it/~mkacimi/lecture5.pdf)
#   - [Reading 2](http://saedsayad.com/decision_tree.htm)
#
# 2. Youtube:
#    - [1](https://www.youtube.com/watch?v=7VeUPuFGJHk)
#    - [2](https://www.youtube.com/watch?v=YtebGVx-Fxw)
#    - [3](https://www.youtube.com/watch?v=zCjLYuLfC7I)

# %% [markdown]
# # Cohen's kappa ($\kappa$)
#
# <b> A statistic that is used to measure inter-rater reliability (and also intra-rater reliability) for qualitative (categorical) items </b>
#
# [Cohen](https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3900052/) suggested the Kappa result be interpreted as follows: values ≤ 0 as indicating no agreement and 0.01–0.20 as none to slight, 0.21–0.40 as fair, 0.41– 0.60 as moderate, 0.61–0.80 as substantial, and 0.81–1.00 as almost perfect agreement.
#
# [Cohen's kappa](https://en.wikipedia.org/wiki/Cohen%27s_kappa) measures the agreement between two raters who each classify N items into C mutually exclusive categories:
#
#
# <center>
# $\large\large\kappa\equiv\frac{p_{o}-p_{e}}{1-p_{e}} $
# </center>
#
# where $p_{o}$ is is the relative observed agreement among raters and $p_{e}$ is the hypothetical probability of chance agreement.

# %% [markdown]
# ## [Simple example](https://en.wikipedia.org/wiki/Cohen%27s_kappa)
#
#
# Suppose that you were analyzing data related to a group of 50 people applying for a grant. Each grant proposal was read by two readers and each reader either said "Yes" or "No" to the proposal.
#
# ![image.png](attachment:image.png)
#
#
# $\large\large p_{o}=\frac{a+d}{a+b+c+d}=\frac{20+15}{50}=0.7 $
# <br>
# </br>
# <br>
# </br>
# $\large\large p_{yes}=\frac{a+b}{a+b+c+d}.\frac{a+c}{a+b+c+d}=0.5x0.6=0.3 $
# <br>
# </br>
# <br>
# </br>
# $\large\large p_{no}=\frac{c+d}{a+b+c+d}.\frac{b+d}{a+b+c+d}=0.5x0.4=0.2 $
# <br>
# </br>
# <br>
# </br>
# $\large\large p_{e}= p_{yes}+p_{no}=0.3+0.2=0.5$
# <br>
# </br>
# <br>
# </br>
# $\large\large\kappa\equiv\frac{p_{o}-p_{e}}{1-p_{e}}=\frac{0.7-0.5}{1-0.5}=0.4 $

# %% [markdown]
# ## Kappa for binary classification confusion matrix
#
# ![image.png](attachment:image.png)
